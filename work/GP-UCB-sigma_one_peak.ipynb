# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt

import BanditProblems as bp

# %%
number_of_action = 1000
number_of_arms   = 100
train_func = bp.train_one_peak
bandit_algo = bp.gp_ucb
x = np.linspace(0, 1, number_of_arms)
y = train_func(x)[1]
train_area = {'mean' : 0.5, 'min' : 0.45, 'max' : 0.55},

# %%
bp.plot_train_func(x,y)

# %%
kernel_sigma = [[0.1, 1], [0.5, 1], [1,1], [3,1], [5,1], [10, 1]]
T = 10
total_rewards = np.array([])
for k in kernel_sigma:
    for i in range(T):
        y_train, x_train = bp.sim_GP(bandit_algo, number_of_action, train_func, x, bp.GP, is_gp_plot=False, kernel_sigma = k)    
        total_rewards = np.append(total_rewards, sum(y_train))
    title = f'kernelsigma_0  = {k[0]}: kernelsigma_1  = {k[1]} reward = {sum(y_train)}'
    bp.plot_transition_action(x_train, number_of_action, train_area, titel = title)
total_rewards = total_rewards.reshape(len(kernel_sigma), T)
print(total_rewards)
# Out:
# [[476. 480.  40. 349. 384. 486. 308. 508. 397. 474.]
#  [460. 419. 452. 313. 331. 461. 460. 449. 475. 159.]
#  [375. 441. 436. 473. 424. 390. 484. 373. 512. 347.]
#  [465. 491. 371. 473. 382. 485. 428. 493. 499. 401.]
#  [442. 395. 417. 420. 437. 486. 496.  22. 479. 396.]
#  [331. 469. 224. 429. 416. 466. 422. 363. 483. 496.]]

# %%
index = 0
t_r = total_rewards
for i in kernel_sigma:
    print(f'ave_reward = {np.mean(t_r[index])} max_r = {np.max(t_r[index])} min_r = {np.min(t_r[index])} var_r = "{round(np.sqrt(np.var(t_r[index])), 2)}" kernel_sigma_0 = "{i[0]}" kernel_sigma_0 = "{i[1]}"')
    index += 1
# Out:
# ave_reward = 390.2 max_r = 508.0 min_r = 40.0 var_r = "132.92" kernel_sigma_0 = "0.1" kernel_sigma_0 = "1"
# ave_reward = 397.9 max_r = 475.0 min_r = 159.0 var_r = "96.11" kernel_sigma_0 = "0.5" kernel_sigma_0 = "1"
# ave_reward = 425.5 max_r = 512.0 min_r = 347.0 var_r = "51.23" kernel_sigma_0 = "1" kernel_sigma_0 = "1"
# ave_reward = 448.8 max_r = 499.0 min_r = 371.0 var_r = "46.52" kernel_sigma_0 = "3" kernel_sigma_0 = "1"
# ave_reward = 399.0 max_r = 496.0 min_r = 22.0 var_r = "130.23" kernel_sigma_0 = "5" kernel_sigma_0 = "1"
# ave_reward = 409.9 max_r = 496.0 min_r = 224.0 var_r = "79.33" kernel_sigma_0 = "10" kernel_sigma_0 = "1"

# %%
kernel_sigma = [[1, 0.01], [1, 0.1], [1,0.5], [1,1], [1,2], [1, 5]]
total_rewards = np.array([])
for k in kernel_sigma:
    for i in range(T):
        y_train, x_train = bp.sim_GP(bandit_algo, number_of_action, train_func, x, bp.GP, is_gp_plot=False, kernel_sigma = k)    
        total_rewards = np.append(total_rewards, sum(y_train))
    title = f'kernelsigma_0  = {k[0]}: kernelsigma_1  = {k[1]} reward = {sum(y_train)}'
    bp.plot_transition_action(x_train, number_of_action, train_area, titel = title)
total_rewards = total_rewards.reshape(len(kernel_sigma), T)
print(total_rewards)
# Out:
# [[468. 442. 424. 455. 265. 278. 512. 232. 495. 438.]
#  [337. 316. 429. 460. 516. 259. 489. 512. 459. 514.]
#  [480. 491. 242. 425. 474. 101. 279. 398. 478. 250.]
#  [280. 508. 475. 365. 399. 246. 448. 497. 434. 527.]
#  [384. 478. 468. 468. 319. 281. 493. 420. 495. 495.]
#  [202. 469. 470. 317. 472. 513. 512. 449.  66. 438.]]

# %%
index = 0
t_r = total_rewards
for i in kernel_sigma:
    print(f'ave_reward = {np.mean(t_r[index])} max_r = {np.max(t_r[index])} min_r = {np.min(t_r[index])} var_r = "{round(np.sqrt(np.var(t_r[index])), 2)}" kernel_sigma_0 = "{i[0]}" kernel_sigma_0 = "{i[1]}"')
    index += 1
# Out:
# ave_reward = 400.9 max_r = 512.0 min_r = 232.0 var_r = "97.12" kernel_sigma_0 = "1" kernel_sigma_0 = "0.01"
# ave_reward = 429.1 max_r = 516.0 min_r = 259.0 var_r = "87.91" kernel_sigma_0 = "1" kernel_sigma_0 = "0.1"
# ave_reward = 361.8 max_r = 491.0 min_r = 101.0 var_r = "127.98" kernel_sigma_0 = "1" kernel_sigma_0 = "0.5"
# ave_reward = 417.9 max_r = 527.0 min_r = 246.0 var_r = "90.79" kernel_sigma_0 = "1" kernel_sigma_0 = "1"
# ave_reward = 430.1 max_r = 495.0 min_r = 281.0 var_r = "73.72" kernel_sigma_0 = "1" kernel_sigma_0 = "2"
# ave_reward = 390.8 max_r = 513.0 min_r = 66.0 var_r = "141.71" kernel_sigma_0 = "1" kernel_sigma_0 = "5"
