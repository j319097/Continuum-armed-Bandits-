# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt

import BanditProblems as bp

# %%
number_of_action = 1000
number_of_arms   = 100
train_func = bp.train_one_peak
bandit_algo = bp.gp_ts
x = np.linspace(0, 1, number_of_arms)
y = train_func(x)[1]
train_area = {'mean' : 0.5, 'min' : 0.45, 'max' : 0.55},

# %%
bp.plot_train_func(x,y)

# %%
kernel_sigma = [[0.1, 1], [0.5, 1], [1,1], [3,1], [5,1], [10, 1]]
T = 10
total_rewards = np.array([])
for k in kernel_sigma:
    for i in range(T):
        y_train, x_train = bp.sim_GP(bandit_algo, number_of_action, train_func, x, bp.GP, is_gp_plot=False, kernel_sigma = k)    
        total_rewards = np.append(total_rewards, sum(y_train))
    title = f'kernelsigma_0  = {k[0]}: kernelsigma_1  = {k[1]} reward = {sum(y_train)}'
    bp.plot_transition_action(x_train, number_of_action, train_area, titel = title)
total_rewards = total_rewards.reshape(len(kernel_sigma), T)
print(total_rewards)
# Out:
# [[440. 475. 305. 477. 451. 474. 256. 454. 321. 475.]
#  [485.  62. 447. 386. 465. 314. 467.  76. 499. 446.]
#  [406. 469. 483. 476. 480. 407. 439. 489. 474. 370.]
#  [514. 482. 495. 224. 396. 489. 487. 232. 251. 520.]
#  [517. 498. 490. 390. 448. 447. 467. 330. 480. 425.]
#  [383.  30. 446.  86. 411. 479. 236. 475. 458. 478.]]

# %%
index = 0
t_r = total_rewards
for i in kernel_sigma:
    print(f'ave_reward = {np.mean(t_r[index])} max_r = {np.max(t_r[index])} min_r = {np.min(t_r[index])} var_r = "{round(np.sqrt(np.var(t_r[index])), 2)}" kernel_sigma_0 = "{i[0]}" kernel_sigma_0 = "{i[1]}"')
    index += 1
# Out:
# ave_reward = 412.8 max_r = 477.0 min_r = 256.0 var_r = "80.08" kernel_sigma_0 = "0.1" kernel_sigma_0 = "1"
# ave_reward = 364.7 max_r = 499.0 min_r = 62.0 var_r = "156.34" kernel_sigma_0 = "0.5" kernel_sigma_0 = "1"
# ave_reward = 449.3 max_r = 489.0 min_r = 370.0 var_r = "39.27" kernel_sigma_0 = "1" kernel_sigma_0 = "1"
# ave_reward = 409.0 max_r = 520.0 min_r = 224.0 var_r = "118.0" kernel_sigma_0 = "3" kernel_sigma_0 = "1"
# ave_reward = 449.2 max_r = 517.0 min_r = 330.0 var_r = "53.12" kernel_sigma_0 = "5" kernel_sigma_0 = "1"
# ave_reward = 348.2 max_r = 479.0 min_r = 30.0 var_r = "161.06" kernel_sigma_0 = "10" kernel_sigma_0 = "1"

# %%
kernel_sigma = [[1, 0.01], [1, 0.1], [1,0.5], [1,1], [1,2], [1, 5]]
total_rewards = np.array([])
for k in kernel_sigma:
    for i in range(T):
        y_train, x_train = bp.sim_GP(bandit_algo, number_of_action, train_func, x, bp.GP, is_gp_plot=False, kernel_sigma = k)    
        total_rewards = np.append(total_rewards, sum(y_train))
    title = f'kernelsigma_0  = {k[0]}: kernelsigma_1  = {k[1]} reward = {sum(y_train)}'
    bp.plot_transition_action(x_train, number_of_action, train_area, titel = title)
total_rewards = total_rewards.reshape(len(kernel_sigma), T)
print(total_rewards)
# Out:
# [[308. 451. 504. 468. 489. 489. 457. 502. 480. 497.]
#  [196. 506. 462. 320. 286. 436. 293. 482. 490. 469.]
#  [206. 376. 517. 493. 437. 338. 437. 505. 268. 465.]
#  [479. 318. 389. 440. 253. 461. 426. 474. 494. 120.]
#  [325. 462. 451. 496. 440. 428. 492. 485. 482. 498.]
#  [424. 463. 480. 392. 492. 368. 474. 454. 478. 409.]]

# %%
index = 0
t_r = total_rewards
for i in kernel_sigma:
    print(f'ave_reward = {np.mean(t_r[index])} max_r = {np.max(t_r[index])} min_r = {np.min(t_r[index])} var_r = "{round(np.sqrt(np.var(t_r[index])), 2)}" kernel_sigma_0 = "{i[0]}" kernel_sigma_0 = "{i[1]}"')
    index += 1
# Out:
# ave_reward = 464.5 max_r = 504.0 min_r = 308.0 var_r = "54.96" kernel_sigma_0 = "1" kernel_sigma_0 = "0.01"
# ave_reward = 394.0 max_r = 506.0 min_r = 196.0 var_r = "103.95" kernel_sigma_0 = "1" kernel_sigma_0 = "0.1"
# ave_reward = 404.2 max_r = 517.0 min_r = 206.0 var_r = "99.81" kernel_sigma_0 = "1" kernel_sigma_0 = "0.5"
# ave_reward = 385.4 max_r = 494.0 min_r = 120.0 var_r = "114.57" kernel_sigma_0 = "1" kernel_sigma_0 = "1"
# ave_reward = 455.9 max_r = 498.0 min_r = 325.0 var_r = "49.44" kernel_sigma_0 = "1" kernel_sigma_0 = "2"
# ave_reward = 443.4 max_r = 492.0 min_r = 368.0 var_r = "40.27" kernel_sigma_0 = "1" kernel_sigma_0 = "5"
